# %% [markdown]
# ## Using ReAct Framework to analyse a stock.
#  - Get the latest stock data from a data source.
#  - Get the stock symbol, its financials
#  - Get the news data headlines from the internet.
#
# * We will use Llama3.1 to do this.

# %%
import json
import sys
import os
from typing import Optional

from llama_index.llms.ollama import Ollama
from llama_index.llms.groq import Groq
from llama_index.core import Settings
# from llama_index.tools.google import GoogleSearchToolSpec
from llama_index.tools.duckduckgo import DuckDuckGoSearchToolSpec
from llama_index.core.tools import BaseTool, FunctionTool
from llama_index.core.agent import ReActAgent
from llama_index.core import PromptTemplate

from dotenv import load_dotenv

# finance tool
import yfinance as yf
import datetime as dt

# get the prompts
sys.path.append(os.path.dirname(os.path.abspath("../stock_analyser_react.ipynb")))
from prompts.react_agent_prompts import LLAMAINDEX_REACT_BASE_PROMPT, STOCK_ANALYSER_PROMPT


# Load the env variables
load_dotenv("../secrets/local.env")
# Out:
# True

# %%
# LLM ollama
# llm = Ollama(model='llama3.1:latest', request_timeout=120.0, temperature=0.01)
# Settings.llm = llm

# LLM Groq
llm = Groq(model="llama-3.1-70b-versatile")
Settings.llm = llm

# %%
stream_response = llm.stream_complete("What is the stock symbol for Bajaj Finance?")

for t in stream_response:
    print(t.delta, end="")


# Note: how the model is hallucinating
# Out:
# The stock symbol for Bajaj Finance is BAJFINANCE.

# %%
# define the tools

    
def multiply(a: int, b: int) -> int:
    """Multiplies two integers and returns the result integer.

    Args:
        a (int): The first integer.
        b (int): The second integer.

    Returns:
        int: The product of a and b.
    """
    return a * b


def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer.

    Args:
        a (int): The first integer.
        b (int): The second integer.
    
    Returns:
        int: The sum of a and b
    """
    return a + b


def subtract(a: int, b: int) -> int:
    """Subtract two integers and returns the result integer
    
    Args:
        a (int): The first integer.
        b (int): The second integer.
    
    Returns:
        int: The sum of a and b
    """
    return a - b


def divide(a: int, b: int) -> int:
    """Divides two integers and returns the result integer.

    Args:
        a (int): The first integer.
        b (int): The second integer.

    Returns:
        int: The quotient of a divided by b.
    """
    return a // b


# yahoo finance financials fetcher
def get_financial_statements(ticker: str) -> str:
    """Fetches the financial statements data from yahoo finance.

    Args:
        ticker (str): The ticker symbol of the company to fetch information for.

    Returns:
        str: A string containing the financial statement data in a formatted way.
    """

    if "." in ticker:
        ticker = ticker.split(".")[0]

    ticker += ".NS"
    company = yf.Ticker(ticker)
    balance_sheet = company.balance_sheet
    if balance_sheet.shape[-1] > 3:
        balance_sheet = balance_sheet.iloc[:, :3]

    balance_sheet = balance_sheet.dropna(how="any")
    balance_sheet = "\n" + balance_sheet.to_string()

    return balance_sheet


# get stock info and recommendations summary
def get_stockinfo(ticker: str) -> str:
    """Provides the detailed financial and general information about the stock ticker.
        Also provides a table for analyst recommendations for the ticker.

    Args:
        ticker (str): The ticker symbol of the company to fetch information for.
    
    Returns:
        str: A string containing the stock info and a summary of recommendations.
    """

    if "." in ticker:
        ticker = ticker.split(".")[0]

    ticker += ".NS"
    company = yf.Ticker(ticker)

    stock_info = company.info
    try:
        recommendations_summary = company.get_recommendations()
    except:
        recommendations_summary = ""

    # TODO: add units and convert to easily understandable units

    include_info = ["industry", "sector", "longBuisnessSummary", "previousClose", "dividendRate", "dividentYield", "beta", "forwardPE", "volume", "marketCap", "fiftyTwoWeekLow", "fiftyTwoWeekHigh", "currency", "bookValue", "priceToBook", "earningsQuarterlyGrowth", "trailingEps", "forwardEps", "52WeekChange", "totalCashPerShare", "ebidta", "totabDebt", "totalCashPerShare", "debtToEquity", "revenuePerShare", "earningsGrowth", "revenueGrowth", "grossMargins", "ebidtaMargins", "operatingMargins", ]
    response = "#### Stock info:\n"

    for key, val in stock_info.items():
        if key in include_info:
            response += f"{key}: {val}\n"

    response += "#### Analyst Recommendations:\n"
    response += f"\n{recommendations_summary}"

    return response


multiply_tool = FunctionTool.from_defaults(fn=multiply)
add_tool = FunctionTool.from_defaults(fn=add)
sub_tool = FunctionTool.from_defaults(fn=subtract)
div_tool = FunctionTool.from_defaults(fn=divide)

# financial sheets
fin_statements = FunctionTool.from_defaults(fn=get_financial_statements)

# stock information and the analyst recommendations
stockinfo = FunctionTool.from_defaults(fn=get_stockinfo)

ddg_tools = DuckDuckGoSearchToolSpec().to_tool_list()
ddg_full_search_tool = ddg_tools[1]
ddg_instant_search_tool = ddg_tools[0]

# %%
multiply.__annotations__
# Out:
# {'a': int, 'b': int, 'return': int}

# %%
ddg_instant_search_tool.metadata
# Out:
# ToolMetadata(description='duckduckgo_instant_search(query: str) -> List[Dict]\n\n        Make a query to DuckDuckGo api to receive an instant answer.\n\n        Args:\n            query (str): The query to be passed to DuckDuckGo.\n        ', name='duckduckgo_instant_search', fn_schema=<class 'llama_index.core.tools.utils.duckduckgo_instant_search'>, return_direct=False)

# %%
# Define a ReactAgent
agent = ReActAgent.from_tools(tools=[ddg_full_search_tool, ddg_instant_search_tool, fin_statements, stockinfo],
                   llm=llm,
                   verbose=True,
                   max_iterations=25,
                   context="You are a top Research Analyst with a Phd in Economics. You analyse equity markets very well and are proficient in creating detailed analysis reports. You do not provide recommendations only analyse company stocks.ƒ")


# have a look at the agent prompt
agent.get_prompts()
# Out:
# {'agent_worker:system_prompt': PromptTemplate(metadata={'prompt_type': <PromptType.CUSTOM: 'custom'>}, template_vars=['tool_desc', 'context', 'tool_names'], kwargs={}, output_parser=None, template_var_mappings=None, function_mappings=None, template='You are designed to help with a variety of tasks, from answering questions to providing summaries to other types of analyses.\n\n## Tools\n\nYou have access to a wide variety of tools. You are responsible for using the tools in any sequence you deem appropriate to complete the task at hand.\nThis may require breaking the task into subtasks and using different tools to complete each subtask.\n\nYou have access to the following tools:\n{tool_desc}\n\nHere is some context to help you answer the question and plan:\n{context}\n\n\n## Output Format\n\nPlease answer in the same language as the question and use the following format:\n\n```\nThought: The current language of the user is: (user\'s language). I need to use a tool to help me answer the question.\nAction: tool name (one of {tool_names}) if using a tool.\nAction Input: the input to the tool, in a JSON format representing the kwargs (e.g. {{"input": "hello world", "num_beams": 5}})\n```\n\nPlease ALWAYS start with a Thought.\n\nNEVER surround your response with markdown code markers. You may use code markers within your response if you need to.\n\nPlease use a valid JSON format for the Action Input. Do NOT do this {{\'input\': \'hello world\', \'num_beams\': 5}}.\n\nIf this format is used, the user will respond in the following format:\n\n```\nObservation: tool response\n```\n\nYou should keep repeating the above format till you have enough information to answer the question without using any more tools. At that point, you MUST respond in the one of the following two formats:\n\n```\nThought: I can answer without using any more tools. I\'ll use the user\'s language to answer\nAnswer: [your answer here (In the same language as the user\'s question)]\n```\n\n```\nThought: I cannot answer the question with the provided tools.\nAnswer: [your answer here (In the same language as the user\'s question)]\n```\n\n## Current Conversation\n\nBelow is the current conversation consisting of interleaving human and assistant messages.\n')}

# %%
# assign the prompt to the agent
stock_analyser_prompt = PromptTemplate(template=STOCK_ANALYSER_PROMPT)
agent.update_prompts(
    {'agent_worker:system_prompt': stock_analyser_prompt}
)

# %%
response = agent.chat("Compare Bajaj Finance and Bajaj Finserv")
# Out:
# > Running step 87fe1a3b-97e6-4c6e-9f26-8868ef17e527. Step input: Compare Bajaj Finance and Bajaj Finserv
# Thought: The current language of the user is: English. I need to extract the company names from the input query.
# Action: Extract
# Action Input: {'companies': ['Bajaj Finance', 'Bajaj Finserv']}
# Observation: Error: No such tool named `Extract`.
# > Running step c1ed79c4-a14e-4d9d-99c2-fd8d717027d1. Step input: None
# Thought: The current language of the user is: English. I need to extract the company names from the input query. Since there is no tool for extraction, I will manually extract the company names and proceed with the analysis.
#
# The company names are Bajaj Finance and Bajaj Finserv.
#
# Next, I need to get the company symbols for Bajaj Finance and Bajaj Finserv by using the "duckduckgo_full_search" tool.
# Action: duckduckgo_full_search
# Action Input: {'query': 'Bajaj Finance NSE/BSE ticker', 'region': 'in', 'max_results': 1}
# Observation: [{'title': 'Bajaj Finance Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJFINANCE', 'body': 'Bajaj Finance Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finance Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}]
# > Running step 69f0d249-a5cb-4504-a400-daca865c8042. Step input: None
# Thought: I have obtained the company symbol for Bajaj Finance, which is BAJFINANCE.
#
# Next, I need to get the company symbol for Bajaj Finserv by using the "duckduckgo_full_search" tool.
# Action: duckduckgo_full_search
# Action Input: {'query': 'Bajaj Finserv NSE/BSE ticker', 'region': 'in', 'max_results': 1}
# Observation: [{'title': 'Bajaj Finserv Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJAJFINSV', 'body': 'Bajaj Finserv Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finserv Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}]
# > Running step af95e83c-dd1c-4325-a04d-e299cc3e9e0b. Step input: None
# Thought: I have obtained the company symbol for Bajaj Finserv, which is BAJAJFINSV.
#
# Next, I need to get the recent news for Bajaj Finance by using the "duckduckgo_full_search" tool.
# Action: duckduckgo_full_search
# Action Input: {'query': 'BAJFINANCE NSE/BSE recent news', 'region': 'in', 'max_results': 5}
# Observation: [{'title': 'Bajaj Finance Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJFINANCE', 'body': 'Bajaj Finance Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finance Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}, {'title': 'Bajaj Finance Share Price, Bajaj Finance Stock Price, Bajaj Finance Ltd ...', 'href': 'https://www.moneycontrol.com/india/stockpricequote/finance-nbfc/bajajfinance/BAF', 'body': 'Bajaj Finance Share Price: Find the latest news on Bajaj Finance Stock Price. Get all the information on Bajaj Finance with historic price charts for NSE / BSE. Experts & Broker view also get the ...'}, {'title': 'Bajaj Finance Ltd (BAJFINANCE) Stock Price & News - Google', 'href': 'https://www.google.com/finance/quote/BAJFINANCE:NSE', 'body': 'Get the latest Bajaj Finance Ltd (BAJFINANCE) real-time quote, historical performance, charts, and other financial information to help you make more informed trading and investment decisions.'}, {'title': 'Bajaj Finance Share Price Today (16 Sep, 2024), Bajaj Finance Stock ...', 'href': 'https://economictimes.indiatimes.com/bajaj-finance-ltd/stocks/companyid-11260.cms', 'body': 'Bajaj Finance Share Price Today (16 Sep, 2024): Bajaj Finance Stock Price (₹ 7345.75) Live NSE/BSE updates on The Economic Times. Check out why Bajaj Finance share price is down today. Get all details on Bajaj Finance shares news and analysis, Forecasts, Dividend, balance sheet, profit & loss, Quarterly results, annual report information, and more'}, {'title': 'Explained: Why Bajaj Finance shares gained over 7% today', 'href': 'https://www.indiatoday.in/business/story/bajaj-finance-rbi-restrictions-lending-products-ecom-insta-emi-card-lifted-shares-gain-2534687-2024-05-03', 'body': "In Short. Shares of Bajaj Finance gained as much as 7.5% in early trade on Friday after announcing that the Reserve Bank of India (RBI) had lifted restrictions on two key lending products after a five-month ban. Today's intraday gain marked the most substantial increase in Bajaj Finance's stock price in nearly two years."}]
# > Running step 867bc7ac-412d-4731-a508-de2762efd574. Step input: None
# Thought: I have obtained the recent news for Bajaj Finance.
#
# Next, I need to get the recent news for Bajaj Finserv by using the "duckduckgo_full_search" tool.
# Action: duckduckgo_full_search
# Action Input: {'query': 'BAJAJFINSV NSE/BSE recent news', 'region': 'in', 'max_results': 5}
# Observation: [{'title': 'Bajaj Finserv Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJAJFINSV', 'body': 'Bajaj Finserv Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finserv Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}, {'title': 'Bajaj Finserv Share Price Today (16 Sep, 2024), Bajaj Finserv Stock ...', 'href': 'https://economictimes.indiatimes.com/bajaj-finserv-ltd/stocks/companyid-21426.cms', 'body': 'Bajaj Finserv Share Price Today (16 Sep, 2024): Bajaj Finserv Stock Price (₹ 1857.60) Live NSE/BSE updates on The Economic Times. Check out why Bajaj Finserv share price is down today. Get all details on Bajaj Finserv shares news and analysis, Forecasts, Dividend, balance sheet, profit & loss, Quarterly results, annual report information, and more'}, {'title': 'Bajaj Finserv News | Bajaj Finserv Announcement, Latest News on Bajaj ...', 'href': 'https://economictimes.indiatimes.com/bajaj-finserv-ltd/stocksupdate/companyid-21426.cms', 'body': 'Bajaj Finserv News - Get the Latest Bajaj Finserv News, Announcements, Photos & Videos on The Economic Times. Stock Quotes: Get all stocks market quotes, company stocks price quotes in India. ... Visit Economic Times to read on Indian companies quotes listed on BSE NSE Stock Exchanges & search share prices by market capitalisation. Benchmarks ...'}, {'title': 'Bajaj Finserv Ltd. Live Share Price, Stock Analysis and ... | Trendlyne', 'href': 'https://trendlyne.com/equity/147/BAJAJFINSV/bajaj-finserv-ltd/', 'body': 'In the past week the stock rose 4.34%. stock has been up 18.67% in the past quarter and rose 20.73% in the past year. You can view this in the overview section. Bajaj Finserv Ltd. live share price at 3:31 p.m. on Sep 9, 2024 is Rs 1860.45. Explore financials, technicals, Deals, Corporate actions and more.'}, {'title': 'Bajaj Finserv Ltd. Share/Stocks Price Live Today NSE | ET Money', 'href': 'https://www.etmoney.com/stocks/bajaj-finserv-ltd/2136', 'body': "NSE: BAJAJFINSVLarge Cap Holding Company ... S&P BSE Dollex - 30, S&P BSE Finance, S&P BSE LargeCap, S&P BSE LargeMidCap, S&P BSE Sensex and S&P BSE Sensex 50. The Latest Details of Bajaj Finserv Ltd.'s ... debt levels, and cash flow. Look into industry trends, competition, and any recent news or developments that might impact Bajaj Finserv ..."}]
# > Running step 7b136daf-4b6d-4b0b-8802-a6bca3a4a196. Step input: None
# Thought: I have obtained the recent news for Bajaj Finserv.
#
# Next, I need to get the financial statements for Bajaj Finance by using the "get_financial_statements" tool.
# Action: get_financial_statements
# Action Input: {'ticker': 'BAJFINANCE'}
# Observation:
#                                                                            2024-03-31       2023-03-31       2022-03-31
# Treasury Shares Number                                                       988329.0        1008401.0        2149392.0
# Ordinary Shares Number                                                    618007991.0      604420832.0      603279841.0
# Share Issued                                                              618996320.0      605429233.0      605429233.0
# Net Debt                                                              2100691200000.0  1611463200000.0  1286728900000.0
# Total Debt                                                            2184371100000.0  1644669400000.0  1328883000000.0
# Tangible Book Value                                                    757856600000.0   536756900000.0   432581000000.0
# Invested Capital                                                      2941313000000.0  2182515500000.0  1761459300000.0
# Net Tangible Assets                                                    757856600000.0   536756900000.0   432581000000.0
# Common Stock Equity                                                    766953500000.0   543719800000.0   437126900000.0
# Total Capitalization                                                  2941313000000.0  2182515500000.0  1761459300000.0
# Total Equity Gross Minority Interest                                   766953500000.0   543719800000.0   437126900000.0
# Stockholders Equity                                                    766953500000.0   543719800000.0   437126900000.0
# Other Equity Interest                                                   10085100000.0     5552600000.0     3971300000.0
# Retained Earnings                                                      370804100000.0   273208900000.0   192519900000.0
# Additional Paid In Capital                                             265820000000.0   174409800000.0   172177700000.0
# Capital Stock                                                            1238000000.0     1210900000.0     1210900000.0
# Common Stock                                                             1238000000.0     1210900000.0     1210900000.0
# Total Liabilities Net Minority Interest                               2990462700000.0  2208543300000.0  1687931700000.0
# Derivative Product Liabilities                                             21200000.0       40100000.0     1400200000.0
# Long Term Debt And Capital Lease Obligation                           2184371100000.0  1644669400000.0  1328883000000.0
# Payables                                                                34820800000.0    26030700000.0    21256600000.0
# Other Payable                                                           13063300000.0    10094900000.0     8663500000.0
# Dividends Payable                                                          30700000.0       22500000.0       17900000.0
# Total Tax Payable                                                        1086400000.0     1392100000.0     1000600000.0
# Accounts Payable                                                        20640400000.0    14521200000.0    11574600000.0
# Total Assets                                                          3757416200000.0  2752263100000.0  2125058600000.0
# Investments And Advances                                               100270700000.0    94522100000.0    54125100000.0
# Investmentin Financial Assets                                           96576500000.0    93578100000.0    54125100000.0
# Available For Sale Securities                                           46739300000.0    26853000000.0    38272600000.0
# Financial Assets Designatedas Fair Value Through Profitor Loss Total    49558800000.0    65236300000.0    14633500000.0
# Long Term Equity Investment                                              3694200000.0      944000000.0              0.0
# Investmentsin Associatesat Cost                                          3694200000.0      944000000.0              0.0
# Goodwill And Other Intangible Assets                                     9096900000.0     6962900000.0     4545900000.0
# Other Intangible Assets                                                  9064200000.0     6930200000.0     4513200000.0
# Goodwill                                                                   32700000.0       32700000.0       32700000.0
# Net PPE                                                                 23836700000.0    16911700000.0    12958500000.0
# Accumulated Depreciation                                               -14428600000.0   -11294900000.0    -9037100000.0
# Gross PPE                                                               38265300000.0    28206600000.0    21995600000.0
# Construction In Progress                                                  253500000.0      146000000.0      132700000.0
# Other Properties                                                         4106400000.0     2771300000.0     1733500000.0
# Machinery Furniture Equipment                                           12051600000.0     9247100000.0     7360600000.0
# Buildings And Improvements                                              19120700000.0    13323100000.0    10802900000.0
# Land And Improvements                                                    2733100000.0     2719100000.0     1965900000.0
# Prepaid Assets                                                           3852000000.0     3414700000.0     2503700000.0
# Receivables                                                             22881100000.0    16141100000.0    14987400000.0
# Taxes Receivable                                                         2909200000.0     1814300000.0     1683000000.0
# Cash And Cash Equivalents                                               73668300000.0    27332500000.0    37603500000.0
# Cash Financial                                                            588400000.0      590700000.0      537200000.0
# Cash Cash Equivalents And Federal Funds Sold                           107994500000.0    44939900000.0    71333200000.0
# > Running step 1085e8ad-0041-4e1c-9d4d-369298791698. Step input: None
# Thought: I have obtained the financial statements for Bajaj Finance.
#
# Next, I need to get the financial statements for Bajaj Finserv by using the "get_financial_statements" tool.
# Action: get_financial_statements
# Action Input: {'ticker': 'BAJAJFINSV'}
# Observation:
#                                                                            2024-03-31       2023-03-31       2022-03-31
# Treasury Shares Number                                                      1360460.0        2041001.0        1714920.0
# Ordinary Shares Number                                                   1594128353.0     1590774459.0     1589659520.0
# Share Issued                                                             1595488813.0     1592815460.0     1591374440.0
# Net Debt                                                              2216828900000.0  1641821000000.0  1256277200000.0
# Total Debt                                                            2287817000000.0  1675994100000.0  1303796600000.0
# Tangible Book Value                                                    585105700000.0   448521200000.0   389493000000.0
# Invested Capital                                                      2877765300000.0  2131830600000.0  1699616800000.0
# Net Tangible Assets                                                    585105700000.0   448521200000.0   389493000000.0
# Capital Lease Obligations                                               13337900000.0     8236900000.0     6647800000.0
# Common Stock Equity                                                    603286200000.0   464073400000.0   402468000000.0
# Total Capitalization                                                  2622657000000.0  2008297400000.0  1585483500000.0
# Total Equity Gross Minority Interest                                  1037758300000.0   775980800000.0   663199200000.0
# Minority Interest                                                      434472100000.0   311907400000.0   260731200000.0
# Stockholders Equity                                                    603286200000.0   464073400000.0   402468000000.0
# Other Equity Interest                                                    6130700000.0     4708900000.0     3771300000.0
# Treasury Stock                                                           1043100000.0     1174800000.0     1199700000.0
# Retained Earnings                                                      362052700000.0   300784100000.0   249497900000.0
# Additional Paid In Capital                                             143996500000.0    96765300000.0    96119200000.0
# Capital Stock                                                            1594100000.0     1592600000.0      795700000.0
# Common Stock                                                             1594100000.0     1592600000.0      795700000.0
# Total Liabilities Net Minority Interest                               4341538000000.0  3279111100000.0  2673990400000.0
# Derivative Product Liabilities                                             61200000.0     1198600000.0     2197100000.0
# Non Current Pension And Other Postretirement Benefit Plans               1034300000.0      635400000.0      483700000.0
# Non Current Deferred Taxes Liabilities                                   5144900000.0     1080400000.0     3057500000.0
# Long Term Debt And Capital Lease Obligation                           2032708700000.0  1552460900000.0  1189663300000.0
# Long Term Capital Lease Obligation                                      13337900000.0     8236900000.0     6647800000.0
# Long Term Debt                                                        2019370800000.0  1544224000000.0  1183015500000.0
# Long Term Provisions                                                     5330400000.0     3417900000.0     2335900000.0
# Current Debt And Capital Lease Obligation                              255108300000.0   123533200000.0   114133300000.0
# Current Debt                                                           255108300000.0   123533200000.0   114133300000.0
# Payables                                                               111780600000.0    85340600000.0    67348200000.0
# Other Payable                                                           34726400000.0    20959400000.0    16065900000.0
# Dividends Payable                                                          36300000.0       27200000.0       22200000.0
# Total Tax Payable                                                       14243700000.0    12301200000.0    11170700000.0
# Accounts Payable                                                        62774200000.0    52052800000.0    40089400000.0
# Total Assets                                                          5379296300000.0  4055091900000.0  3337189600000.0
# Non Current Deferred Taxes Assets                                       10281700000.0    10235600000.0     9511700000.0
# Financial Assets                                                         5911700000.0     2265000000.0     1366300000.0
# Investments And Advances                                              1699198900000.0  1370110000000.0  1201411900000.0
# Investmentin Financial Assets                                          944896700000.0   786248900000.0   793045800000.0
# Available For Sale Securities                                           70409600000.0    57830900000.0   108800000000.0
# Financial Assets Designatedas Fair Value Through Profitor Loss Total   868575400000.0   726153000000.0   682879500000.0
# Long Term Equity Investment                                              3827600000.0     1073200000.0      133700000.0
# Investmentsin Joint Venturesat Cost                                      3827600000.0     1073200000.0      133700000.0
# Investment Properties                                                     301300000.0      348500000.0      355900000.0
# Goodwill And Other Intangible Assets                                    18180500000.0    15552200000.0    12975000000.0
# Other Intangible Assets                                                 11287100000.0     8658800000.0     6081600000.0
# Goodwill                                                                 6893400000.0     6893400000.0     6893400000.0
# Net PPE                                                                 38272400000.0    29372100000.0    23653000000.0
# Accumulated Depreciation                                               -25449100000.0   -21029500000.0   -17943200000.0
# Gross PPE                                                               63721500000.0    50401600000.0    41596200000.0
# Construction In Progress                                                  821200000.0      618400000.0      536400000.0
# Other Properties                                                        26896600000.0    18567600000.0    14419400000.0
# Machinery Furniture Equipment                                           17862800000.0    13590600000.0    11235600000.0
# Buildings And Improvements                                              11396100000.0    10898200000.0    10649700000.0
# Land And Improvements                                                    6744800000.0     6726800000.0     4755100000.0
# Prepaid Assets                                                            247400000.0      438000000.0      700200000.0
# Other Receivables                                                       26374200000.0    18234500000.0    18127900000.0
# Taxes Receivable                                                        11230800000.0    10268100000.0     7207600000.0
# Accounts Receivable                                                     59738600000.0    34586400000.0    30048100000.0
# Cash Cash Equivalents And Short Term Investments                       808124800000.0   608724100000.0   449104000000.0
# Other Short Term Investments                                           750474600000.0   582787900000.0   408232400000.0
# Cash And Cash Equivalents                                               57650200000.0    25936200000.0    40871600000.0
# > Running step 4867be12-0fb0-441f-9e62-2abcd5cde76d. Step input: None
# Thought: I have obtained the financial statements for Bajaj Finserv.
#
# Next, I need to get the stock information and recommendations for Bajaj Finance by using the "get_stockinfo_recommendations" tool.
# Action: get_stockinfo_recommendations
# Action Input: {'ticker': 'BAJFINANCE'}
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/BAJFINANCE.NS?modules=recommendationTrend&corsDomain=finance.yahoo.com&formatted=false&symbol=BAJFINANCE.NS&crumb=ZjbBJqK%2FSM8
# Observation: #### Stock info:
# industry: Credit Services
# sector: Financial Services
# previousClose: 7345.75
# dividendRate: 36.0
# beta: 1.017
# volume: 1567645
# marketCap: 4555488100352
# fiftyTwoWeekLow: 6187.8
# fiftyTwoWeekHigh: 8192.0
# currency: INR
# bookValue: 1241.009
# priceToBook: 5.9350896
# earningsQuarterlyGrowth: 0.138
# trailingEps: 242.41
# 52WeekChange: -0.026878953
# totalCashPerShare: 145.924
# debtToEquity: 305.489
# revenuePerShare: 537.325
# earningsGrowth: 0.115
# revenueGrowth: 0.18
# grossMargins: 0.93878996
# operatingMargins: 0.60258
# #### Analyst Recommendations:
#
# Empty DataFrame
# Columns: []
# Index: []
# > Running step e9f4c8d2-86da-4d70-99a6-ed91dfb5c1a7. Step input: None
# Thought: I have obtained the stock information and recommendations for Bajaj Finance.
#
# Next, I need to get the stock information and recommendations for Bajaj Finserv by using the "get_stockinfo_recommendations" tool.
# Action: get_stockinfo_recommendations
# Action Input: {'ticker': 'BAJAJFINSV'}
# Observation: #### Stock info:
# industry: Financial Conglomerates
# sector: Financial Services
# previousClose: 1857.6
# dividendRate: 1.0
# beta: 1.061
# forwardPE: 37.4155
# volume: 1919900
# marketCap: 2946920349696
# fiftyTwoWeekLow: 1419.05
# fiftyTwoWeekHigh: 1921.0
# currency: INR
# bookValue: 378.443
# priceToBook: 4.8850155
# earningsQuarterlyGrowth: 0.1
# trailingEps: 51.83
# forwardEps: 49.41
# 52WeekChange: 0.19080734
# totalCashPerShare: 77.378
# debtToEquity: 220.46
# revenuePerShare: 734.966
# earningsGrowth: 0.099
# revenueGrowth: 0.349
# grossMargins: 0.50356996
# operatingMargins: 0.37357
# #### Analyst Recommendations:
#
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          0    0     0     0           0
# 1    -1m          0    0     0     0           0
# 2    -2m          0    0     0     0           0
# 3    -3m          0    0     0     0           0
# > Running step 2a67074a-71f0-420a-bc2e-7e8596622209. Step input: None
# Thought: I have obtained the stock information and recommendations for Bajaj Finserv.
#
# Now, I will consolidate the gathered data in a PROS & CONS manner to get the final answer backed-up with numbers to justify.
#
# Bajaj Finance and Bajaj Finserv are both financial services companies with a strong presence in India. Here's a comparison of their key metrics:
#
# **Bajaj Finance:**
#
# Pros:
#
# * Higher market capitalization (4555488100352) compared to Bajaj Finserv (2946920349696)
# * Higher revenue growth (0.18) compared to Bajaj Finserv (0.349)
# * Higher earnings growth (0.115) compared to Bajaj Finserv (0.099)
# * Higher gross margins (0.93878996) compared to Bajaj Finserv (0.50356996)
#
# Cons:
#
# * Lower price-to-book ratio (5.9350896) compared to Bajaj Finserv (4.8850155)
# * Lower dividend rate (36.0) compared to Bajaj Finserv (1.0)
# * Higher debt-to-equity ratio (305.489) compared to Bajaj Finserv (220.46)
#
# **Bajaj Finserv:**
#
# Pros:
#
# * Higher price-to-book ratio (4.8850155) compared to Bajaj Finance (5.9350896)
# * Higher dividend rate (1.0) compared to Bajaj Finance (36.0)
# * Lower debt-to-equity ratio (220.46) compared to Bajaj Finance (305.489)
#
# Cons:
#
# * Lower market capitalization (2946920349696) compared to Bajaj Finance (4555488100352)
# * Lower revenue growth (0.349) compared to Bajaj Finance (0.18)
# * Lower earnings growth (0.099) compared to Bajaj Finance (0.115)
# * Lower gross margins (0.50356996) compared to Bajaj Finance (0.93878996)
#
# Based on the analysis, Bajaj Finance seems to have a stronger financial position and higher growth potential, but Bajaj Finserv has a more attractive valuation and lower debt levels. However, it's essential to note that both companies have their strengths and weaknesses, and the decision to invest in either company should be based on individual financial goals and risk tolerance.
# Answer: Bajaj Finance and Bajaj Finserv are both strong financial services companies with their unique strengths and weaknesses. Bajaj Finance has a stronger financial position and higher growth potential, while Bajaj Finserv has a more attractive valuation and lower debt levels. I am just an AI Research analyst assistant. I am not a financial advisor. I don't provide investment advice or recommendations.

# %%
response
# Out:
# AgentChatResponse(response="Bajaj Finance and Bajaj Finserv are both strong financial services companies with their unique strengths and weaknesses. Bajaj Finance has a stronger financial position and higher growth potential, while Bajaj Finserv has a more attractive valuation and lower debt levels. I am just an AI Research analyst assistant. I am not a financial advisor. I don't provide investment advice or recommendations.", sources=[ToolOutput(content='Error: No such tool named `Extract`.', tool_name='Extract', raw_input={'kwargs': {'companies': ['Bajaj Finance', 'Bajaj Finserv']}}, raw_output='Error: No such tool named `Extract`.', is_error=True), ToolOutput(content="[{'title': 'Bajaj Finance Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJFINANCE', 'body': 'Bajaj Finance Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finance Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}]", tool_name='duckduckgo_full_search', raw_input={'args': (), 'kwargs': {'query': 'Bajaj Finance NSE/BSE ticker', 'region': 'in', 'max_results': 1}}, raw_output=[{'title': 'Bajaj Finance Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJFINANCE', 'body': 'Bajaj Finance Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finance Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}], is_error=False), ToolOutput(content="[{'title': 'Bajaj Finserv Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJAJFINSV', 'body': 'Bajaj Finserv Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finserv Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}]", tool_name='duckduckgo_full_search', raw_input={'args': (), 'kwargs': {'query': 'Bajaj Finserv NSE/BSE ticker', 'region': 'in', 'max_results': 1}}, raw_output=[{'title': 'Bajaj Finserv Limited Share Price Today, Stock Price, Live NSE News ...', 'href': 'https://www.nseindia.com/get-quotes/equity?symbol=BAJAJFINSV', 'body': 'Bajaj Finserv Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finserv Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.'}], is_error=False), ToolOutput(content='[{\'title\': \'Bajaj Finance Limited Share Price Today, Stock Price, Live NSE News ...\', \'href\': \'https://www.nseindia.com/get-quotes/equity?symbol=BAJFINANCE\', \'body\': \'Bajaj Finance Limited Share Price Today, Live NSE Stock Price: Get the latest Bajaj Finance Limited news, company updates, quotes, offers, annual financial reports, graph, volumes, 52 week high low, buy sell tips, balance sheet, historical charts, market performance, capitalisation, dividends, volume, profit and loss account, research, results and more details at NSE India.\'}, {\'title\': \'Bajaj Finance Share Price, Bajaj Finance Stock Price, Bajaj Finance Ltd ...\', \'href\': \'https://www.moneycontrol.com/india/stockpricequote/finance-nbfc/bajajfin ...
